# %%
from sweetviz import make_animation

# %%
# you can edit this function to include the road layout, but this currently makes files really big
make_animation("/home/gerstenecker/PlanT_2_cleanup/PlanT/final_results/fourth_both_1/1/viz/02.txt", "test.svg", "", 124219, duration=50, control=True, fps=8)
